# %% [markdown]
# <a href="https://colab.research.google.com/github/ari1idont/Gas_CNN/blob/main/gas8c7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
from tensorflow import keras
from sklearn.model_selection import train_test_split

# %%
ds_total_x=pd.read_csv('net_dataset_x.csv')
ds_total_y=pd.read_csv('net_dataset_y.csv')

# %%
ds_total_x=ds_total_x.drop('Unnamed: 0',axis=1)
ds_total_y=ds_total_y.drop('Unnamed: 0',axis=1)

# %%
total_x=ds_total_x.to_numpy(dtype='float32')
total_y=ds_total_y.to_numpy(dtype='float32')

# %%
train_x,test_x,train_y,test_y=train_test_split(total_x,total_y,test_size=0.15,random_state=False)

# %%
train_x = train_x.reshape((train_x.shape[0], train_x.shape[1], 1))
test_x = test_x.reshape((test_x.shape[0], test_x.shape[1], 1))

# %%
num_classes = len(np.unique(train_y))

# %%
print(num_classes)
# Out:
# 31

# %%
def make_model(input_shape):
    input_layer = keras.layers.Input(input_shape)

    conv1 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(input_layer)
    conv1 = keras.layers.BatchNormalization()(conv1)
    conv1 = keras.layers.ReLU()(conv1)

    conv2 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv1)
    conv2 = keras.layers.BatchNormalization()(conv2)
    conv2 = keras.layers.ReLU()(conv2)

    conv3 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv2)
    conv3 = keras.layers.BatchNormalization()(conv3)
    conv3 = keras.layers.ReLU()(conv3)

    conv4 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv3)
    conv4 = keras.layers.BatchNormalization()(conv4)
    conv4 = keras.layers.ReLU()(conv4)

    conv5 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv4)
    conv5 = keras.layers.BatchNormalization()(conv5)
    conv5 = keras.layers.ReLU()(conv5)

    conv6 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv5)
    conv6 = keras.layers.BatchNormalization()(conv6)
    conv6 = keras.layers.ReLU()(conv6)

    conv7 = keras.layers.Conv1D(filters=64, kernel_size=3, padding="same")(conv6)
    conv7 = keras.layers.BatchNormalization()(conv7)
    conv7 = keras.layers.ReLU()(conv7)

    gap = keras.layers.GlobalAveragePooling1D()(conv7)

    output_layer = keras.layers.Dense(num_classes, activation="softmax")(gap)

    return keras.models.Model(inputs=input_layer, outputs=output_layer)


model = make_model(input_shape=train_x.shape[1:])
keras.utils.plot_model(model, show_shapes=True)

# %%
epochs = 100
batch_size = 32

callbacks = [
    keras.callbacks.ModelCheckpoint(
        "best_model.h5", save_best_only=True, monitor="val_loss"
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=20, min_lr=0.0001
    ),
    keras.callbacks.EarlyStopping(monitor="val_loss", patience=50, verbose=1),
]
model.compile(
    optimizer="adam",
    loss="sparse_categorical_crossentropy",
    metrics=["sparse_categorical_accuracy"],
)
history = model.fit(
    train_x,
    train_y,
    batch_size=batch_size,
    epochs=epochs,
    callbacks=callbacks,
    validation_split=0.2,
    verbose=1,
)
# Out:
# Epoch 1/100
# 6165/6165 [==============================] - 56s 8ms/step - loss: 0.8651 - sparse_categorical_accuracy: 0.6574 - val_loss: 0.6551 - val_sparse_categorical_accuracy: 0.7347 - lr: 0.0010
# Epoch 2/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.6962 - sparse_categorical_accuracy: 0.7189 - val_loss: 0.5747 - val_sparse_categorical_accuracy: 0.7641 - lr: 0.0010
# Epoch 3/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.6240 - sparse_categorical_accuracy: 0.7454 - val_loss: 0.5486 - val_sparse_categorical_accuracy: 0.7691 - lr: 0.0010
# Epoch 4/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.5749 - sparse_categorical_accuracy: 0.7653 - val_loss: 0.4873 - val_sparse_categorical_accuracy: 0.7963 - lr: 0.0010
# Epoch 5/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.5505 - sparse_categorical_accuracy: 0.7752 - val_loss: 0.5820 - val_sparse_categorical_accuracy: 0.7518 - lr: 0.0010
# Epoch 6/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.5259 - sparse_categorical_accuracy: 0.7840 - val_loss: 0.4966 - val_sparse_categorical_accuracy: 0.7948 - lr: 0.0010
# Epoch 7/100
# 6165/6165 [==============================] - 48s 8ms/step - loss: 0.5086 - sparse_categorical_accuracy: 0.7911 - val_loss: 0.4495 - val_sparse_categorical_accuracy: 0.8236 - lr: 0.0010
# Epoch 8/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4969 - sparse_categorical_accuracy: 0.7963 - val_loss: 0.5426 - val_sparse_categorical_accuracy: 0.7751 - lr: 0.0010
# Epoch 9/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.4850 - sparse_categorical_accuracy: 0.8010 - val_loss: 0.4130 - val_sparse_categorical_accuracy: 0.8308 - lr: 0.0010
# Epoch 10/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4768 - sparse_categorical_accuracy: 0.8039 - val_loss: 0.4601 - val_sparse_categorical_accuracy: 0.8136 - lr: 0.0010
# Epoch 11/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.4689 - sparse_categorical_accuracy: 0.8072 - val_loss: 0.4700 - val_sparse_categorical_accuracy: 0.8062 - lr: 0.0010
# Epoch 12/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4579 - sparse_categorical_accuracy: 0.8122 - val_loss: 0.6704 - val_sparse_categorical_accuracy: 0.7576 - lr: 0.0010
# Epoch 13/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.4559 - sparse_categorical_accuracy: 0.8126 - val_loss: 0.4081 - val_sparse_categorical_accuracy: 0.8322 - lr: 0.0010
# Epoch 14/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4464 - sparse_categorical_accuracy: 0.8171 - val_loss: 0.3964 - val_sparse_categorical_accuracy: 0.8384 - lr: 0.0010
# Epoch 15/100
# 6165/6165 [==============================] - 48s 8ms/step - loss: 0.4425 - sparse_categorical_accuracy: 0.8180 - val_loss: 0.4036 - val_sparse_categorical_accuracy: 0.8296 - lr: 0.0010
# Epoch 16/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.4385 - sparse_categorical_accuracy: 0.8197 - val_loss: 0.4302 - val_sparse_categorical_accuracy: 0.8199 - lr: 0.0010
# Epoch 17/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4366 - sparse_categorical_accuracy: 0.8200 - val_loss: 0.3794 - val_sparse_categorical_accuracy: 0.8465 - lr: 0.0010
# Epoch 18/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.4286 - sparse_categorical_accuracy: 0.8231 - val_loss: 0.4119 - val_sparse_categorical_accuracy: 0.8270 - lr: 0.0010
# Epoch 19/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.4267 - sparse_categorical_accuracy: 0.8237 - val_loss: 0.4725 - val_sparse_categorical_accuracy: 0.8023 - lr: 0.0010
# Epoch 20/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.4234 - sparse_categorical_accuracy: 0.8255 - val_loss: 0.3982 - val_sparse_categorical_accuracy: 0.8369 - lr: 0.0010
# Epoch 21/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.4193 - sparse_categorical_accuracy: 0.8272 - val_loss: 0.4246 - val_sparse_categorical_accuracy: 0.8259 - lr: 0.0010
# Epoch 22/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.4183 - sparse_categorical_accuracy: 0.8273 - val_loss: 0.3964 - val_sparse_categorical_accuracy: 0.8374 - lr: 0.0010
# Epoch 23/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.4134 - sparse_categorical_accuracy: 0.8298 - val_loss: 0.3743 - val_sparse_categorical_accuracy: 0.8488 - lr: 0.0010
# Epoch 24/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4118 - sparse_categorical_accuracy: 0.8310 - val_loss: 0.3685 - val_sparse_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 25/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.4075 - sparse_categorical_accuracy: 0.8321 - val_loss: 0.3776 - val_sparse_categorical_accuracy: 0.8467 - lr: 0.0010
# Epoch 26/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4053 - sparse_categorical_accuracy: 0.8336 - val_loss: 0.3633 - val_sparse_categorical_accuracy: 0.8534 - lr: 0.0010
# Epoch 27/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4047 - sparse_categorical_accuracy: 0.8330 - val_loss: 0.3703 - val_sparse_categorical_accuracy: 0.8450 - lr: 0.0010
# Epoch 28/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.4011 - sparse_categorical_accuracy: 0.8345 - val_loss: 0.3952 - val_sparse_categorical_accuracy: 0.8344 - lr: 0.0010
# Epoch 29/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.4004 - sparse_categorical_accuracy: 0.8349 - val_loss: 0.3891 - val_sparse_categorical_accuracy: 0.8369 - lr: 0.0010
# Epoch 30/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.3978 - sparse_categorical_accuracy: 0.8367 - val_loss: 0.3579 - val_sparse_categorical_accuracy: 0.8534 - lr: 0.0010
# Epoch 31/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3945 - sparse_categorical_accuracy: 0.8370 - val_loss: 0.3686 - val_sparse_categorical_accuracy: 0.8504 - lr: 0.0010
# Epoch 32/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3945 - sparse_categorical_accuracy: 0.8378 - val_loss: 0.3529 - val_sparse_categorical_accuracy: 0.8555 - lr: 0.0010
# Epoch 33/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3942 - sparse_categorical_accuracy: 0.8372 - val_loss: 0.3700 - val_sparse_categorical_accuracy: 0.8478 - lr: 0.0010
# Epoch 34/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.3918 - sparse_categorical_accuracy: 0.8389 - val_loss: 0.3648 - val_sparse_categorical_accuracy: 0.8507 - lr: 0.0010
# Epoch 35/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3895 - sparse_categorical_accuracy: 0.8394 - val_loss: 0.3467 - val_sparse_categorical_accuracy: 0.8582 - lr: 0.0010
# Epoch 36/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3884 - sparse_categorical_accuracy: 0.8402 - val_loss: 0.4384 - val_sparse_categorical_accuracy: 0.8196 - lr: 0.0010
# Epoch 37/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3881 - sparse_categorical_accuracy: 0.8404 - val_loss: 0.3589 - val_sparse_categorical_accuracy: 0.8516 - lr: 0.0010
# Epoch 38/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3870 - sparse_categorical_accuracy: 0.8407 - val_loss: 0.4002 - val_sparse_categorical_accuracy: 0.8331 - lr: 0.0010
# Epoch 39/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.3856 - sparse_categorical_accuracy: 0.8406 - val_loss: 0.3588 - val_sparse_categorical_accuracy: 0.8540 - lr: 0.0010
# Epoch 40/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3839 - sparse_categorical_accuracy: 0.8414 - val_loss: 0.3567 - val_sparse_categorical_accuracy: 0.8548 - lr: 0.0010
# Epoch 41/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3823 - sparse_categorical_accuracy: 0.8423 - val_loss: 0.3587 - val_sparse_categorical_accuracy: 0.8542 - lr: 0.0010
# Epoch 42/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3819 - sparse_categorical_accuracy: 0.8427 - val_loss: 0.3433 - val_sparse_categorical_accuracy: 0.8591 - lr: 0.0010
# Epoch 43/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3788 - sparse_categorical_accuracy: 0.8442 - val_loss: 0.3787 - val_sparse_categorical_accuracy: 0.8423 - lr: 0.0010
# Epoch 44/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3781 - sparse_categorical_accuracy: 0.8448 - val_loss: 0.3897 - val_sparse_categorical_accuracy: 0.8356 - lr: 0.0010
# Epoch 45/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3779 - sparse_categorical_accuracy: 0.8441 - val_loss: 0.3444 - val_sparse_categorical_accuracy: 0.8568 - lr: 0.0010
# Epoch 46/100
# 6165/6165 [==============================] - 52s 9ms/step - loss: 0.3754 - sparse_categorical_accuracy: 0.8453 - val_loss: 0.3459 - val_sparse_categorical_accuracy: 0.8575 - lr: 0.0010
# Epoch 47/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3755 - sparse_categorical_accuracy: 0.8451 - val_loss: 0.3424 - val_sparse_categorical_accuracy: 0.8635 - lr: 0.0010
# Epoch 48/100
# 6165/6165 [==============================] - 54s 9ms/step - loss: 0.3753 - sparse_categorical_accuracy: 0.8456 - val_loss: 0.4408 - val_sparse_categorical_accuracy: 0.8184 - lr: 0.0010
# Epoch 49/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3742 - sparse_categorical_accuracy: 0.8461 - val_loss: 0.3519 - val_sparse_categorical_accuracy: 0.8560 - lr: 0.0010
# Epoch 50/100
# 6165/6165 [==============================] - 54s 9ms/step - loss: 0.3725 - sparse_categorical_accuracy: 0.8468 - val_loss: 0.3406 - val_sparse_categorical_accuracy: 0.8607 - lr: 0.0010
# Epoch 51/100
# 6165/6165 [==============================] - 52s 9ms/step - loss: 0.3716 - sparse_categorical_accuracy: 0.8476 - val_loss: 0.4211 - val_sparse_categorical_accuracy: 0.8285 - lr: 0.0010
# Epoch 52/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3707 - sparse_categorical_accuracy: 0.8476 - val_loss: 0.3391 - val_sparse_categorical_accuracy: 0.8605 - lr: 0.0010
# Epoch 53/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3714 - sparse_categorical_accuracy: 0.8472 - val_loss: 0.3403 - val_sparse_categorical_accuracy: 0.8594 - lr: 0.0010
# Epoch 54/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3694 - sparse_categorical_accuracy: 0.8474 - val_loss: 0.3416 - val_sparse_categorical_accuracy: 0.8627 - lr: 0.0010
# Epoch 55/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3680 - sparse_categorical_accuracy: 0.8480 - val_loss: 0.3485 - val_sparse_categorical_accuracy: 0.8554 - lr: 0.0010
# Epoch 56/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3672 - sparse_categorical_accuracy: 0.8483 - val_loss: 0.3650 - val_sparse_categorical_accuracy: 0.8491 - lr: 0.0010
# Epoch 57/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3678 - sparse_categorical_accuracy: 0.8492 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.8657 - lr: 0.0010
# Epoch 58/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3661 - sparse_categorical_accuracy: 0.8500 - val_loss: 0.3517 - val_sparse_categorical_accuracy: 0.8540 - lr: 0.0010
# Epoch 59/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3655 - sparse_categorical_accuracy: 0.8499 - val_loss: 0.3628 - val_sparse_categorical_accuracy: 0.8506 - lr: 0.0010
# Epoch 60/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3648 - sparse_categorical_accuracy: 0.8499 - val_loss: 0.3384 - val_sparse_categorical_accuracy: 0.8615 - lr: 0.0010
# Epoch 61/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3635 - sparse_categorical_accuracy: 0.8506 - val_loss: 0.3839 - val_sparse_categorical_accuracy: 0.8375 - lr: 0.0010
# Epoch 62/100
# 6165/6165 [==============================] - 49s 8ms/step - loss: 0.3638 - sparse_categorical_accuracy: 0.8501 - val_loss: 0.3465 - val_sparse_categorical_accuracy: 0.8563 - lr: 0.0010
# Epoch 63/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3619 - sparse_categorical_accuracy: 0.8511 - val_loss: 0.3332 - val_sparse_categorical_accuracy: 0.8627 - lr: 0.0010
# Epoch 64/100
# 6165/6165 [==============================] - 52s 9ms/step - loss: 0.3634 - sparse_categorical_accuracy: 0.8505 - val_loss: 0.3546 - val_sparse_categorical_accuracy: 0.8552 - lr: 0.0010
# Epoch 65/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3617 - sparse_categorical_accuracy: 0.8503 - val_loss: 0.3524 - val_sparse_categorical_accuracy: 0.8534 - lr: 0.0010
# Epoch 66/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3613 - sparse_categorical_accuracy: 0.8516 - val_loss: 0.3393 - val_sparse_categorical_accuracy: 0.8613 - lr: 0.0010
# Epoch 67/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3610 - sparse_categorical_accuracy: 0.8511 - val_loss: 0.3455 - val_sparse_categorical_accuracy: 0.8575 - lr: 0.0010
# Epoch 68/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3594 - sparse_categorical_accuracy: 0.8524 - val_loss: 0.4094 - val_sparse_categorical_accuracy: 0.8338 - lr: 0.0010
# Epoch 69/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3585 - sparse_categorical_accuracy: 0.8518 - val_loss: 0.3612 - val_sparse_categorical_accuracy: 0.8502 - lr: 0.0010
# Epoch 70/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3575 - sparse_categorical_accuracy: 0.8530 - val_loss: 0.3477 - val_sparse_categorical_accuracy: 0.8583 - lr: 0.0010
# Epoch 71/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3589 - sparse_categorical_accuracy: 0.8512 - val_loss: 0.3334 - val_sparse_categorical_accuracy: 0.8639 - lr: 0.0010
# Epoch 72/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3571 - sparse_categorical_accuracy: 0.8529 - val_loss: 0.3916 - val_sparse_categorical_accuracy: 0.8355 - lr: 0.0010
# Epoch 73/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3553 - sparse_categorical_accuracy: 0.8531 - val_loss: 0.3235 - val_sparse_categorical_accuracy: 0.8679 - lr: 0.0010
# Epoch 74/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3557 - sparse_categorical_accuracy: 0.8534 - val_loss: 0.3220 - val_sparse_categorical_accuracy: 0.8694 - lr: 0.0010
# Epoch 75/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3557 - sparse_categorical_accuracy: 0.8536 - val_loss: 0.3296 - val_sparse_categorical_accuracy: 0.8666 - lr: 0.0010
# Epoch 76/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3552 - sparse_categorical_accuracy: 0.8539 - val_loss: 0.3394 - val_sparse_categorical_accuracy: 0.8598 - lr: 0.0010
# Epoch 77/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3541 - sparse_categorical_accuracy: 0.8537 - val_loss: 0.3171 - val_sparse_categorical_accuracy: 0.8702 - lr: 0.0010
# Epoch 78/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3541 - sparse_categorical_accuracy: 0.8541 - val_loss: 0.3386 - val_sparse_categorical_accuracy: 0.8616 - lr: 0.0010
# Epoch 79/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3545 - sparse_categorical_accuracy: 0.8537 - val_loss: 0.3701 - val_sparse_categorical_accuracy: 0.8470 - lr: 0.0010
# Epoch 80/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3532 - sparse_categorical_accuracy: 0.8544 - val_loss: 0.3869 - val_sparse_categorical_accuracy: 0.8409 - lr: 0.0010
# Epoch 81/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3526 - sparse_categorical_accuracy: 0.8551 - val_loss: 0.3309 - val_sparse_categorical_accuracy: 0.8651 - lr: 0.0010
# Epoch 82/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3520 - sparse_categorical_accuracy: 0.8550 - val_loss: 0.3332 - val_sparse_categorical_accuracy: 0.8628 - lr: 0.0010
# Epoch 83/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3504 - sparse_categorical_accuracy: 0.8555 - val_loss: 0.3305 - val_sparse_categorical_accuracy: 0.8649 - lr: 0.0010
# Epoch 84/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3520 - sparse_categorical_accuracy: 0.8548 - val_loss: 0.3294 - val_sparse_categorical_accuracy: 0.8668 - lr: 0.0010
# Epoch 85/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3516 - sparse_categorical_accuracy: 0.8553 - val_loss: 0.3485 - val_sparse_categorical_accuracy: 0.8549 - lr: 0.0010
# Epoch 86/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3508 - sparse_categorical_accuracy: 0.8557 - val_loss: 0.3318 - val_sparse_categorical_accuracy: 0.8612 - lr: 0.0010
# Epoch 87/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3492 - sparse_categorical_accuracy: 0.8559 - val_loss: 0.3274 - val_sparse_categorical_accuracy: 0.8661 - lr: 0.0010
# Epoch 88/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3499 - sparse_categorical_accuracy: 0.8560 - val_loss: 0.3617 - val_sparse_categorical_accuracy: 0.8494 - lr: 0.0010
# Epoch 89/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3494 - sparse_categorical_accuracy: 0.8561 - val_loss: 0.3329 - val_sparse_categorical_accuracy: 0.8621 - lr: 0.0010
# Epoch 90/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3481 - sparse_categorical_accuracy: 0.8564 - val_loss: 0.3312 - val_sparse_categorical_accuracy: 0.8651 - lr: 0.0010
# Epoch 91/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3492 - sparse_categorical_accuracy: 0.8559 - val_loss: 0.3216 - val_sparse_categorical_accuracy: 0.8680 - lr: 0.0010
# Epoch 92/100
# 6165/6165 [==============================] - 50s 8ms/step - loss: 0.3472 - sparse_categorical_accuracy: 0.8566 - val_loss: 0.3281 - val_sparse_categorical_accuracy: 0.8663 - lr: 0.0010
# Epoch 93/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3463 - sparse_categorical_accuracy: 0.8575 - val_loss: 0.3494 - val_sparse_categorical_accuracy: 0.8571 - lr: 0.0010
# Epoch 94/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3470 - sparse_categorical_accuracy: 0.8573 - val_loss: 0.3200 - val_sparse_categorical_accuracy: 0.8693 - lr: 0.0010
# Epoch 95/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3465 - sparse_categorical_accuracy: 0.8574 - val_loss: 0.3205 - val_sparse_categorical_accuracy: 0.8694 - lr: 0.0010
# Epoch 96/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3458 - sparse_categorical_accuracy: 0.8586 - val_loss: 0.3209 - val_sparse_categorical_accuracy: 0.8692 - lr: 0.0010
# Epoch 97/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3463 - sparse_categorical_accuracy: 0.8579 - val_loss: 0.3347 - val_sparse_categorical_accuracy: 0.8598 - lr: 0.0010
# Epoch 98/100
# 6165/6165 [==============================] - 53s 9ms/step - loss: 0.3226 - sparse_categorical_accuracy: 0.8676 - val_loss: 0.3038 - val_sparse_categorical_accuracy: 0.8760 - lr: 5.0000e-04
# Epoch 99/100
# 6165/6165 [==============================] - 52s 8ms/step - loss: 0.3217 - sparse_categorical_accuracy: 0.8678 - val_loss: 0.3119 - val_sparse_categorical_accuracy: 0.8729 - lr: 5.0000e-04
# Epoch 100/100
# 6165/6165 [==============================] - 51s 8ms/step - loss: 0.3193 - sparse_categorical_accuracy: 0.8688 - val_loss: 0.3357 - val_sparse_categorical_accuracy: 0.8622 - lr: 5.0000e-04

# %%
test_loss, test_acc = model.evaluate(test_x, test_y)

print("Test accuracy", test_acc)
print("Test loss", test_loss)
# Out:
# 1360/1360 [==============================] - 4s 3ms/step - loss: 0.3340 - sparse_categorical_accuracy: 0.8610
# Test accuracy 0.8609808683395386
# Test loss 0.33395087718963623

# %%
metric = "sparse_categorical_accuracy"
plt.figure()
plt.plot(history.history[metric])
plt.plot(history.history["val_" + metric])
plt.title("model " + metric)
plt.ylabel(metric, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
metric1 = "loss"
plt.figure()
plt.plot(history.history[metric1])
plt.plot(history.history["val_" + metric1])
plt.title("model " + metric1)
plt.ylabel(metric1, fontsize="large")
plt.xlabel("epoch", fontsize="large")
plt.legend(["train", "val"], loc="best")
plt.show()
plt.close()

# %%
y_pred=model.predict(test_x)
res=[]
for i in y_pred:
  res.append(np.argmax(i))
print(res)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sns
data = confusion_matrix(test_y, res)
df_cm = pd.DataFrame(data, columns=np.unique(test_y), index = np.unique(test_y))
df_cm.index.name = 'Actual'
df_cm.columns.name = 'Predicted'
sns.heatmap(df_cm, cmap="Blues", annot=True,annot_kws={"size": 5})# font size

# %%
confusion_mat=np.array(data)
as1=pd.DataFrame(confusion_mat)
as1.to_excel('c_mat.xlsx')
